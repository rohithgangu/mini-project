# %% [markdown]
# # project on ipl data

# %% [markdown]
# * to display the count of matches based on year wise

# %%
import pandas as pd
df= pd.read_csv('C:/Users/Rohith Reddy/Desktop/problem solving and programming/datafiles/match.csv')
df
# Out:
#      Match_SK  match_id                        Team1  \
# 0           0    335987  Royal Challengers Bangalore
# 1           1    335988              Kings XI Punjab
# 2           2    335989             Delhi Daredevils
# 3           3    335990               Mumbai Indians
# 4           4    335991        Kolkata Knight Riders
# 5           5    335992             Rajasthan Royals
# 6           6    335993              Deccan Chargers
# 7           7    335994          Chennai Super Kings
# 8           8    335995              Deccan Chargers
# 9           9    335996              Kings XI Punjab
# 10         10    335997  Royal Challengers Bangalore
# 11         11    335998          Chennai Super Kings
# 12         12    335999               Mumbai Indians
# 13         13    336000              Kings XI Punjab
# 14         14    336001  Royal Challengers Bangalore
# 15         15    336002        Kolkata Knight Riders
# 16         16    336003             Delhi Daredevils
# ...

# %% [markdown]
# # to display no of matches played in a year

# %%
df['Season_Year'].value_counts()
# Out:
# 2013    76
# 2012    74
# 2011    73
# 2017    60
# 2016    60
# 2014    60
# 2010    60
# 2015    59
# 2008    58
# 2009    57
# Name: Season_Year, dtype: int64

# %% [markdown]
# # to plot a bar graph on number of matches won by each team in 2011

# %%
#df=df[df.Season_Year == 2011]
print(df)
# Out:
#      Match_SK  match_id                        Team1  \
# 175       175    501203          Chennai Super Kings
# 176       176    501204              Deccan Chargers
# 177       177    501205         Kochi Tuskers Kerala
# 178       178    501206             Delhi Daredevils
# 179       179    501207                Pune Warriors
# 180       180    501208        Kolkata Knight Riders
# 181       181    501209             Rajasthan Royals
# 182       182    501210  Royal Challengers Bangalore
# 183       183    501211              Kings XI Punjab
# 184       184    501212                Pune Warriors
# 185       185    501213              Deccan Chargers
# 186       186    501214             Rajasthan Royals
# 187       187    501215               Mumbai Indians
# 188       188    501216          Chennai Super Kings
# 189       189    501217              Deccan Chargers
# 190       190    501218                Pune Warriors
# 191       191    501219        Kolkata Knight Riders
# ...

# %%
df
#[match_winner].value_counts(
# Out:
#      Match_SK  match_id                        Team1  \
# 175       175    501203          Chennai Super Kings
# 176       176    501204              Deccan Chargers
# 177       177    501205         Kochi Tuskers Kerala
# 178       178    501206             Delhi Daredevils
# 179       179    501207                Pune Warriors
# 180       180    501208        Kolkata Knight Riders
# 181       181    501209             Rajasthan Royals
# 182       182    501210  Royal Challengers Bangalore
# 183       183    501211              Kings XI Punjab
# 184       184    501212                Pune Warriors
# 185       185    501213              Deccan Chargers
# 186       186    501214             Rajasthan Royals
# 187       187    501215               Mumbai Indians
# 188       188    501216          Chennai Super Kings
# 189       189    501217              Deccan Chargers
# 190       190    501218                Pune Warriors
# 191       191    501219        Kolkata Knight Riders
# ...

# %%
#df=df['match_winner'].value_counts()
#print(df)
# Out:
# Chennai Super Kings            11
# Mumbai Indians                 10
# Royal Challengers Bangalore    10
# Kolkata Knight Riders           8
# Kings XI Punjab                 7
# Deccan Chargers                 6
# Kochi Tuskers Kerala            6
# Rajasthan Royals                6
# Delhi Daredevils                4
# Pune Warriors                   4
# Name: match_winner, dtype: int64

# %%
import numpy as np
import matplotlib.pyplot as plt
pt=df[df['Season_Year'] == 2011]
lr=pt['match_winner'].value_counts()
pd.DataFrame(lr)
print(lr)
print()
teams=[]
teams=lr.index.tolist()
plt.bar(teams,lr,color="#1412cd",width=0.3)
# Out:
# Chennai Super Kings            11
# Mumbai Indians                 10
# Royal Challengers Bangalore    10
# Kolkata Knight Riders           8
# Kings XI Punjab                 7
# Deccan Chargers                 6
# Kochi Tuskers Kerala            6
# Rajasthan Royals                6
# Delhi Daredevils                4
# Pune Warriors                   4
# Name: match_winner, dtype: int64
# <BarContainer object of 10 artists>

# %% [markdown]
# # Print  ManOfMatch count of each player in  Hyderabad stadium

# %%
df=df[df.City_Name == 'Hyderabad']
df
# Out:
#      Match_SK  match_id                Team1                        Team2  \
# 6           6    335993      Deccan Chargers             Delhi Daredevils
# 8           8    335995      Deccan Chargers             Rajasthan Royals
# 17         17    336004      Deccan Chargers              Kings XI Punjab
# 20         20    336007      Deccan Chargers  Royal Challengers Bangalore
# 32         32    336019      Deccan Chargers        Kolkata Knight Riders
# 42         42    336029      Deccan Chargers               Mumbai Indians
# 54         54    336042      Deccan Chargers          Chennai Super Kings
# 176       176    501204      Deccan Chargers             Rajasthan Royals
# 185       185    501213      Deccan Chargers  Royal Challengers Bangalore
# 189       189    501217      Deccan Chargers              Kings XI Punjab
# 200       200    501229      Deccan Chargers               Mumbai Indians
# 215       215    501244      Deccan Chargers        Kolkata Knight Riders
# ...

# %%
df=df['ManOfMach'].value_counts()
print(df)
# Out:
# DA Warner            6
# DW Steyn             3
# V Sehwag             2
# YK Pathan            2
# GH Vihari            2
# SK Raina             2
# A Mishra             2
# G Gambhir            1
# Mandeep Singh        1
# R Vinay Kumar        1
# DJ Bravo             1
# B Kumar              1
# DJG Sammy            1
# UT Yadav             1
# MR Marsh             1
# CH Morris            1
# AT Rayudu            1
# SE Marsh             1
# I Sharma             1
# V Kohli              1
# SC Ganguly           1
# MJ McClenaghan       1
# Mustafizur Rahman    1
# PA Patel             1
# SK Trivedi           1
# WP Saha              1
# SL Malinga           1
# PC Valthaty          1
# AB Dinda             1
# Name: ManOfMach, dtype: int64
